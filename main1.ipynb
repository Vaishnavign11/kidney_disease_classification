# %%
#pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\vaish\\OneDrive\\Documents\\MiniProject\\kidney_disease.csv')

# %%
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
import numpy as np

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\vaish\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\vaish\anaconda3\lib\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\vaish\anaconda3\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\vaish\anaconda3\lib\site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vaish\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\vaish\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vaish\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vaish\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\vaish\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\vaish\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\vaish\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vaish\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vaish\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\vaish\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\vaish\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# C:\Users\vaish\anaconda3\Lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedWriter name=4>
#   return process_handler(cmd, _system_body)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\vaish\anaconda3\Lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=5>
#   return process_handler(cmd, _system_body)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\vaish\anaconda3\Lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=6>
#   return process_handler(cmd, _system_body)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
#  17  wc              295 non-null    object
#  18  rc              270 non-null    object
#  19  htn             398 non-null    object
#  20  dm              398 non-null    object
#  21  cad             398 non-null    object
#  22  appet           399 non-null    object
#  23  pe              399 non-null    object
#  24  ane             399 non-null    object
#  25  classification  400 non-null    object
# dtypes: float64(11), int64(1), object(14)
# memory usage: 81.4+ KB

# %%
df.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (400, 26)

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\vaish\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\vaish\anaconda3\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\vaish\anaconda3\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\vaish\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\vaish\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.
# C:\Users\vaish\anaconda3\Lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedWriter name=4>
#   return process_handler(cmd, _system_body)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\vaish\anaconda3\Lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=5>
#   return process_handler(cmd, _system_body)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\vaish\anaconda3\Lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=6>
#   return process_handler(cmd, _system_body)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
df['rbc']=lb.fit_transform(df['rbc'])

# %%
df['pc']=lb.fit_transform(df['pc'])

# %%
df['pcc']=lb.fit_transform(df['pcc'])

# %%
df['ba']=lb.fit_transform(df['ba'])

# %%
df['htn']=lb.fit_transform(df['htn'])

# %%
df['dm']=lb.fit_transform(df['dm'])

# %%
df['cad']=lb.fit_transform(df['cad'])

# %%
df['appet']=lb.fit_transform(df['appet'])

# %%
df['pe']=lb.fit_transform(df['pe'])

# %%
df['ane']=lb.fit_transform(df['ane'])

# %%
df['classification']=lb.fit_transform(df['classification'])

# %%
df['classification']=lb.fit_transform(df['classification'])

# %%
print(df)
# Out:
#       id   age    bp     sg   al   su  rbc  pc  pcc  ba  ...  pcv    wc   rc  \
# 0      0  48.0  80.0  1.020  1.0  0.0    2   1    0   0  ...   44  7800  5.2
# 1      1   7.0  50.0  1.020  4.0  0.0    2   1    0   0  ...   38  6000  NaN
# 2      2  62.0  80.0  1.010  2.0  3.0    1   1    0   0  ...   31  7500  NaN
# 3      3  48.0  70.0  1.005  4.0  0.0    1   0    1   0  ...   32  6700  3.9
# 4      4  51.0  80.0  1.010  2.0  0.0    1   1    0   0  ...   35  7300  4.6
# ..   ...   ...   ...    ...  ...  ...  ...  ..  ...  ..  ...  ...   ...  ...
# 395  395  55.0  80.0  1.020  0.0  0.0    1   1    0   0  ...   47  6700  4.9
# 396  396  42.0  70.0  1.025  0.0  0.0    1   1    0   0  ...   54  7800  6.2
# 397  397  12.0  80.0  1.020  0.0  0.0    1   1    0   0  ...   49  6600  5.4
# 398  398  17.0  60.0  1.025  0.0  0.0    1   1    0   0  ...   51  7200  5.9
# 399  399  58.0  80.0  1.025  0.0  0.0    1   1    0   0  ...   53  6800  6.1
#
#      htn  dm  cad appet pe ane  classification
# 0      1   4    1     0  0   0               0
# 1      0   3    1     0  0   0               0
# 2      0   4    1     1  0   1               0
# 3      1   3    1     1  1   1               0
# 4      0   3    1     0  0   0               0
# ..   ...  ..  ...   ... ..  ..             ...
# 395    0   3    1     0  0   0               2
# 396    0   3    1     0  0   0               2
# 397    0   3    1     0  0   0               2
# 398    0   3    1     0  0   0               2
# 399    0   3    1     0  0   0               2
#
# [400 rows x 26 columns]

# %%
df['age']=df['age'].fillna(df['age'].mean())

# %%
df.replace('\t?', float('nan'), inplace=True)  # Replace '\t?' with NaN

# %%
columns_to_convert = [ 'bp',     'sg',   'al' ,  'su',  'rbc',  'pc',  'pcc' , 'ba'  ,'bgr', 'bu', 'sc', 'sod', 'pot' ,'hemo' ,'pcv' , 'wc' , 'rc' ,'htn',  'dm'  ,'cad',  'appet' , 'pe' , 'ane' , 'classification']  # Replace with the actual column names

# %%
for column in columns_to_convert:
    df[column] = pd.to_numeric(df[column], errors='coerce')

# %%
df.dropna(inplace=True)

# %%
pip install fancyimpute
# Out:
# Requirement already satisfied: fancyimpute in c:\users\vaish\anaconda3\lib\site-packages (0.7.0)
# Requirement already satisfied: knnimpute>=0.1.0 in c:\users\vaish\anaconda3\lib\site-packages (from fancyimpute) (0.1.0)
# Requirement already satisfied: scikit-learn>=0.24.2 in c:\users\vaish\anaconda3\lib\site-packages (from fancyimpute) (1.3.0)
# Requirement already satisfied: cvxpy in c:\users\vaish\anaconda3\lib\site-packages (from fancyimpute) (1.4.1)
# Requirement already satisfied: cvxopt in c:\users\vaish\anaconda3\lib\site-packages (from fancyimpute) (1.3.2)
# Requirement already satisfied: pytest in c:\users\vaish\anaconda3\lib\site-packages (from fancyimpute) (7.4.0)
# Requirement already satisfied: nose in c:\users\vaish\anaconda3\lib\site-packages (from fancyimpute) (1.3.7)
# Requirement already satisfied: six in c:\users\vaish\anaconda3\lib\site-packages (from knnimpute>=0.1.0->fancyimpute) (1.16.0)
# Requirement already satisfied: numpy>=1.10 in c:\users\vaish\anaconda3\lib\site-packages (from knnimpute>=0.1.0->fancyimpute) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\vaish\anaconda3\lib\site-packages (from scikit-learn>=0.24.2->fancyimpute) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\vaish\anaconda3\lib\site-packages (from scikit-learn>=0.24.2->fancyimpute) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\vaish\anaconda3\lib\site-packages (from scikit-learn>=0.24.2->fancyimpute) (2.2.0)
# Requirement already satisfied: osqp>=0.6.2 in c:\users\vaish\anaconda3\lib\site-packages (from cvxpy->fancyimpute) (0.6.3)
# Requirement already satisfied: ecos>=2 in c:\users\vaish\anaconda3\lib\site-packages (from cvxpy->fancyimpute) (2.0.12)
# Requirement already satisfied: clarabel>=0.5.0 in c:\users\vaish\anaconda3\lib\site-packages (from cvxpy->fancyimpute) (0.6.0)
# Requirement already satisfied: scs>=3.0 in c:\users\vaish\anaconda3\lib\site-packages (from cvxpy->fancyimpute) (3.2.4.post1)
# Requirement already satisfied: pybind11 in c:\users\vaish\anaconda3\lib\site-packages (from cvxpy->fancyimpute) (2.11.1)
# Requirement already satisfied: iniconfig in c:\users\vaish\anaconda3\lib\site-packages (from pytest->fancyimpute) (1.1.1)
# Requirement already satisfied: packaging in c:\users\vaish\anaconda3\lib\site-packages (from pytest->fancyimpute) (23.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\vaish\anaconda3\lib\site-packages (from pytest->fancyimpute) (1.0.0)
# Requirement already satisfied: colorama in c:\users\vaish\anaconda3\lib\site-packages (from pytest->fancyimpute) (0.4.6)
# Requirement already satisfied: qdldl in c:\users\vaish\anaconda3\lib\site-packages (from osqp>=0.6.2->cvxpy->fancyimpute) (0.1.7.post0)
# Note: you may need to restart the kernel to use updated packages.
# C:\Users\vaish\anaconda3\Lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedWriter name=4>
#   return process_handler(cmd, _system_body)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\vaish\anaconda3\Lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=5>
#   return process_handler(cmd, _system_body)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\vaish\anaconda3\Lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=6>
#   return process_handler(cmd, _system_body)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %%
#from fancyimpute import KNN

# %%
# knn_imputer = KNN()
# df = knn_imputer.fit_transform(df)

# %%
# df = knn_imputer.fit_transform(df)

# %%
df=pd.DataFrame(df,columns=['id',   'age',   'bp',     'sg',   'al' ,  'su',  'rbc',  'pc',  'pcc' , 'ba'  ,'bgr', 'bu', 'sc', 'sod', 'pot' ,'hemo' ,'pcv' , 'wc' , 'rc' ,'htn',  'dm'  ,'cad',  'appet' , 'pe' , 'ane' , 'classification'])

# %%
df=pd.DataFrame(df,columns=['id',   'age',   'bp',     'sg',   'al' ,  'su',  'rbc',  'pc',  'pcc' , 'ba'  ,'bgr', 'bu', 'sc', 'sod', 'pot' ,'hemo' ,'pcv' , 'wc' , 'rc' ,'htn',  'dm'  ,'cad',  'appet' , 'pe' , 'ane' , 'classification'])

# %%
df.head(30)
# Out:
#     id   age     bp     sg   al   su  rbc  pc  pcc  ba  ...   pcv       wc  \
# 3    3  48.0   70.0  1.005  4.0  0.0    1   0    1   0  ...  32.0   6700.0
# 5    5  60.0   90.0  1.015  3.0  0.0    2   2    0   0  ...  39.0   7800.0
# 9    9  53.0   90.0  1.020  2.0  0.0    0   0    1   0  ...  29.0  12100.0
# 11  11  63.0   70.0  1.010  3.0  0.0    0   0    1   0  ...  32.0   4500.0
# 12  12  68.0   70.0  1.015  3.0  1.0    2   1    1   0  ...  28.0  12200.0
# 14  14  68.0   80.0  1.010  3.0  2.0    1   0    1   1  ...  16.0  11000.0
# 15  15  40.0   80.0  1.015  3.0  0.0    2   1    0   0  ...  24.0   3800.0
# 18  18  60.0  100.0  1.025  0.0  3.0    2   1    0   0  ...  37.0  11400.0
# 20  20  61.0   80.0  1.015  2.0  0.0    0   0    0   0  ...  24.0   9200.0
# 22  22  48.0   80.0  1.025  4.0  0.0    1   0    0   0  ...  32.0   6900.0
# 25  25  61.0   60.0  1.025  0.0  0.0    2   1    0   0  ...  29.0   8400.0
# 26  26  75.0   80.0  1.015  0.0  0.0    2   1    0   0  ...  35.0  10300.0
# 27  27  69.0   70.0  1.010  3.0  4.0    1   0    0   0  ...  37.0   9600.0
# 31  31  73.0   90.0  1.015  3.0  0.0    2   0    1   0  ...  30.0   7800.0
# 32  32  61.0   90.0  1.010  1.0  1.0    2   1    0   0  ...  34.0   9600.0
# 39  39  82.0   80.0  1.010  2.0  2.0    1   2    0   0  ...  40.0   9800.0
# 42  42  47.0  100.0  1.010  0.0  0.0    2   1    0   0  ...  33.0   9200.0
# 43  43  35.0   80.0  1.010  1.0  0.0    0   2    0   0  ...  24.0   7900.0
# 46  46  48.0   70.0  1.015  0.0  0.0    2   1    0   0  ...  37.0   6400.0
# 48  48  73.0   70.0  1.005  0.0  0.0    1   1    0   0  ...  29.0  18900.0
# 58  58  73.0   80.0  1.020  2.0  0.0    0   0    0   0  ...  33.0   7200.0
# 62  62  15.0   60.0  1.020  3.0  0.0    2   1    0   0  ...  33.0   7700.0
# 70  70  61.0   80.0  1.015  0.0  4.0    2   1    0   0  ...  44.0   8300.0
# 71  71  46.0   60.0  1.010  1.0  0.0    1   1    0   0  ...  28.0  14600.0
# 74  74  56.0   90.0  1.015  2.0  0.0    0   0    0   0  ...  29.0   6400.0
# 76  76  48.0   80.0  1.005  4.0  0.0    0   0    0   1  ...  36.0   6200.0
# 77  77  67.0   70.0  1.010  1.0  0.0    2   1    0   0  ...  34.0   7100.0
# 80  80  74.0   80.0  1.010  0.0  0.0    2   1    0   0  ...  31.0   9400.0
# 84  84  59.0   70.0  1.010  3.0  0.0    1   0    0   0  ...  22.0   3800.0
# 90  90  63.0  100.0  1.010  2.0  2.0    1   1    0   1  ...  40.0   9800.0
#
#      rc  htn  dm  cad  appet  pe  ane  classification
# 3   3.9    1   3    1      1   1    1               0
# 5   4.4    1   4    1      0   1    0               0
# 9   3.7    1   4    1      1   0    1               0
# 11  3.8    1   4    1      1   1    0               0
# 12  3.4    1   4    2      1   1    0               0
# 14  2.6    1   4    2      1   1    0               0
# 15  2.8    1   3    1      0   0    1               0
# 18  4.3    1   4    2      0   0    0               0
# 20  3.2    1   4    2      1   1    1               0
# 22  3.4    1   3    1      0   0    1               0
# 25  3.7    1   4    1      0   0    1               0
# 26  4.0    1   4    1      1   0    0               0
# 27  4.1    1   4    2      0   1    0               0
# 31  4.0    0   3    1      1   0    0               0
# 32  4.0    1   4    1      1   0    0               0
# 39  4.2    1   4    1      0   0    0               0
# 42  4.5    1   3    1      0   0    1               0
# 43  3.1    0   4    1      0   0    0               0
# 46  4.7    0   4    1      0   0    0               0
# 48  3.5    1   4    1      0   1    0               0
# 58  4.3    1   4    2      0   0    0               0
# 62  3.8    1   4    1      0   0    0               0
# 70  5.2    1   4    1      0   0    0               0
# 71  3.2    1   4    1      0   0    0               0
# 74  3.4    1   3    1      0   0    0               0
# 76  4.0    0   4    1      0   1    0               0
# 77  3.7    1   4    1      0   1    0               0
# 80  3.8    1   4    1      0   0    0               0
# 84  2.1    1   3    1      1   1    1               0
# 90  4.2    1   3    2      0   0    0               0
#
# [30 rows x 26 columns]

# %%
#y=df['classification'][0:203]

# %%
#X=df.drop(df['classification'])

# %%
from sklearn.model_selection import train_test_split

# %%
# X_train,X_test,y_train,y_test = train_test_split(df,test_size=0.2,random_state=101)
# x_train=df.drop(['id', 'classification'], axis=1)
# y_train=df["classification"]
# x_test=df.drop(['id', 'classification'], axis=1)
# y_test=df["classification"]
X = df.drop(['id', 'classification'], axis=1)
y = df['classification']

# Split the data into training and testing sets
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
#from sklearn.neighbors import KNeighborsClassifier

# %%
#knn=KNeighborsClassifier(n_neighbors=2)

# %%
#knn.fit(X_train,y_train)

# %%
#y_pred = knn.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix,mean_absolute_error,accuracy_score

# %%
#print(classification_report(y_test,y_pred))

# %%
#confusion_matrix(y_test,y_pred)

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(X_train,y_train)
y_pred1 = rf.predict(X_test)
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        28
#            2       0.97      1.00      0.99        34
#
#     accuracy                           0.98        62
#    macro avg       0.99      0.98      0.98        62
# weighted avg       0.98      0.98      0.98        62

# %%
print("Accuracy score is:",accuracy_score(y_test,y_pred1)*100)
# Out:
# Accuracy score is: 98.38709677419355

# %%
import pickle

# Save the model
filename = 'trained_model2.sav'
with open(filename, 'wb') as file:
    pickle.dump(rf, file)

# Load the model
with open(filename, 'rb') as file:
    loaded_model = pickle.load(file)
